# %% [markdown]
# ## Pandas Plot Series DataFrame

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame()

# %% [markdown]
# ### plot
# #### kind : str
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot.

# %%
ts = pd.Series(np.random.randn(1000),
             index=pd.date_range('1/1/2000', periods=1000))

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                 index=ts.index, columns=list('ABCD'))

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = df.cumsum()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()

# %%
df3.head()
# Out:
#           B         C
# 0  0.073926 -1.638148
# 1  0.936693 -1.330950
# 2 -0.697861 -1.684564
# 3 -1.520493  0.590959
# 4 -1.506743  1.652077

# %%
df3["A"] = pd.Series(list(range(len(df))))

# %%
df3.head()
# Out:
#           B         C  A
# 0  0.073926 -1.638148  0
# 1  0.936693 -1.330950  1
# 2 -0.697861 -1.684564  2
# 3 -1.520493  0.590959  3
# 4 -1.506743  1.652077  4

# %%
df3.plot(x="A", y="B");
