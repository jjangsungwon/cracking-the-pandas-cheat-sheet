# %% [markdown]
# ## Area Plot
# - 공식문서 : https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.063452  0.547607  0.043049  0.238527
# 1  0.948987  0.479878  0.641051  0.377992
# 2  0.293379  0.437177  0.605587  0.694833
# 3  0.304729  0.359953  0.657214  0.043828
# 4  0.588780  0.784172  0.266328  0.222801

# %%
df.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(grid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=False, grid=True)
# Out:
# <AxesSubplot:>
